# %%
import os
import re
import numpy as np

from robosuite.models.objects import MujocoXMLObject
from robosuite.utils.mjcf_utils import xml_path_completion

from libero.libero.envs.base_object import register_object

import pathlib

from libero.libero.envs.base_object import (
    register_visual_change_object,
    register_object,
)
from libero.libero.utils.mu_utils import register_mu, InitialSceneTemplates
from libero.libero.utils.task_generation_utils import register_task_info, get_task_info, generate_bddl_from_task_info
# Out:
# [robosuite WARNING] No private macro file found! (macros.py:53)
# [robosuite WARNING] It is recommended to use a private macro file (macros.py:54)
# [robosuite WARNING] To setup, run: python /home/achapin/miniconda3/envs/libero/lib/python3.8/site-packages/robosuite/scripts/setup_macros.py (macros.py:55)

# %% [markdown]
# ## Define your own objects
# You may want to include more object meshes of yours in the procedural generation pipeline. One option is to include your assets and define your object directly inside the LIBERO codebase. But this can make the whole thing messy.
#
# Alternatively, you can define the objects inside your custom project repo folder, and define the object classes accordingly. Note that you need to import your defined object classes whenever you run your own stuff. Libero codebase cannot automatically import those that are defined outside its repo.
#
# In the next, we provide an example, assuming you have object meses defined in `custom_assets`. In this example, we assume the generated pddl file will be saved in `custom_pddl`.

# %%
class CustomObjects(MujocoXMLObject):
    def __init__(self, custom_path, name, obj_name, joints=[dict(type="free", damping="0.0005")]):
        # make sure custom path is an absolute path
        assert(os.path.isabs(custom_path)), "Custom path must be an absolute path"
        # make sure the custom path is also an xml file
        assert(custom_path.endswith(".xml")), "Custom path must be an xml file"
        super().__init__(
            custom_path,
            name=name,
            joints=joints,
            obj_type="all",
            duplicate_collision_geoms=False,
        )
        self.category_name = "_".join(
            re.sub(r"([A-Z])", r" \1", self.__class__.__name__).split()
        ).lower()
        self.object_properties = {"vis_site_names": {}}

@register_object
class LiberoMug(CustomObjects):
    def __init__(self,
                 name="libero_mug",
                 obj_name="libero_mug",
                 ):
        super().__init__(
            custom_path=os.path.abspath(os.path.join(
                "./", "custom_assets", "libero_mug", "libero_mug.xml"
            )),
            name=name,
            obj_name=obj_name,
        )

        self.rotation = {
            "x": (-np.pi/2, -np.pi/2),
            "y": (-np.pi, -np.pi),
            "z": (np.pi, np.pi),
        }
        self.rotation_axis = None

@register_object
class LiberoMugYellow(CustomObjects):
    def __init__(self,
                 name="libero_mug",
                 obj_name="libero_mug",
                 ):
        super().__init__(
            custom_path=os.path.abspath(os.path.join(
                "./", "custom_assets", "libero_mug_yellow", "libero_mug_yellow.xml"
            )),
            name=name,
            obj_name=obj_name,
        )

        self.rotation = {
            "x": (-np.pi/2, -np.pi/2),
            "y": (-np.pi, -np.pi),
            "z": (np.pi, np.pi),
        }
        self.rotation_axis = None

# %%
@register_object 
class PowerDrill(CustomObjects):
    def __init__(self,
                 name="power_drill",
                 obj_name="power_drill",
                 ):
        super().__init__(
            custom_path=os.path.abspath(os.path.join(
                "./", "custom_assets", "power_drill","power_drill", "power_drill.xml"
            )),
            name=name,
            obj_name=obj_name,
        )

        self.rotation = {
            "x": (-np.pi/2, -np.pi/2),
            "y": (-np.pi, -np.pi),
            "z": (np.pi, np.pi),
        }
        self.rotation_axis = None

# %% [markdown]
# ### Define the scene
# Now we define the scene to load the previously defined objects. For more information about the scene genration, please look at `procedural_creation_walkthrough.ipynb`.

# %%
import re
from libero.libero.envs import objects
from libero.libero.utils.bddl_generation_utils import *
from libero.libero.envs.objects import OBJECTS_DICT
from libero.libero.utils.object_utils import get_affordance_regions

from libero.libero.utils.mu_utils import register_mu, InitialSceneTemplates

@register_mu(scene_type="kitchen")
class KitchenDemoScene(InitialSceneTemplates):
    def __init__(self):

        fixture_num_info = {
            "kitchen_table": 1,
            "wooden_cabinet": 1,
        }

        object_num_info = {
            "libero_mug": 1,
            "power_drill": 1,
            # "libero_mug_red": 1,
        }

        super().__init__(
            workspace_name="kitchen_table",
            fixture_num_info=fixture_num_info,
            object_num_info=object_num_info,
        )

    def define_regions(self):
        self.regions.update(
            self.get_region_dict(
                region_centroid_xy=[0.0, -0.30],
                region_name="wooden_cabinet_init_region",
                target_name=self.workspace_name,
                region_half_len=0.01,
                yaw_rotation=(np.pi, np.pi),
            )
        )

        self.regions.update(
            self.get_region_dict(
                region_centroid_xy=[0.0, 0.0],
                region_name="libero_mug_init_region",
                target_name=self.workspace_name,
                region_half_len=0.025,
            )
        )

        self.regions.update(
            self.get_region_dict(
                region_centroid_xy=[-0.1, 0.15],
                region_name="power_drill_init_region",
                target_name=self.workspace_name,
                region_half_len=0.025,
            )
        )
        """self.regions.update(
            self.get_region_dict(
                region_centroid_xy=[-0.2, 0.2],
                region_name="libero_mug_red_init_region",
                target_name=self.workspace_name,
                region_half_len=0.025,
            )
        )"""
        self.xy_region_kwargs_list = get_xy_region_kwargs_list_from_regions_info(
            self.regions
        )

    @property
    def init_states(self):
        states = [
            ("On", "libero_mug_1", "kitchen_table_libero_mug_init_region"),
            ("On", "power_drill_1", "kitchen_table_power_drill_init_region"),
            #("On", "libero_mug_red_1", "kitchen_table_libero_mug_red_init_region"),
            ("On", "wooden_cabinet_1", "kitchen_table_wooden_cabinet_init_region"),
        ]
        return states

# %%
scene_name = "kitchen_demo_scene"
language = "libero demo behaviors"
register_task_info(language,
                   scene_name=scene_name,
                   objects_of_interest=[],
                   goal_states=[
                       ("Open", "wooden_cabinet_1_top_region"),
                       #("In", "power_drill_1", "wooden_cabinet_1_top_region"),
                       ],
)

YOUR_BDDL_FILE_PATH = "./custom_pddl"
bddl_file_names, failures = generate_bddl_from_task_info(folder=YOUR_BDDL_FILE_PATH)
print(bddl_file_names)

print("Encountered some failures: ", failures)

with open(bddl_file_names[0], "r") as f:
    print(f.read())

from libero.libero.envs import OffScreenRenderEnv
from IPython.display import display
from PIL import Image

import torch
import torchvision


env_args = {
    "bddl_file_name": bddl_file_names[0],
    "camera_heights": 256,
    "camera_widths": 256
}

env = OffScreenRenderEnv(**env_args)
obs = env.reset()
display(Image.fromarray(obs["agentview_image"][::-1]))
# Out:
# ./custom_pddl/KITCHEN_DEMO_SCENE_libero_demo_behaviors.bddl
# ./custom_pddl/KITCHEN_DEMO_SCENE_libero_demo_behaviors.bddl
# ./custom_pddl/KITCHEN_DEMO_SCENE_libero_demo_behaviors.bddl
# ./custom_pddl/KITCHEN_DEMO_SCENE_libero_demo_behaviors.bddl
# ./custom_pddl/KITCHEN_DEMO_SCENE_libero_demo_behaviors.bddl
# Succefully generated: 6
# ['./custom_pddl/KITCHEN_DEMO_SCENE_libero_demo_behaviors.bddl', './custom_pddl/KITCHEN_DEMO_SCENE_libero_demo_behaviors.bddl', './custom_pddl/KITCHEN_DEMO_SCENE_libero_demo_behaviors.bddl', './custom_pddl/KITCHEN_DEMO_SCENE_libero_demo_behaviors.bddl', './custom_pddl/KITCHEN_DEMO_SCENE_libero_demo_behaviors.bddl', './custom_pddl/KITCHEN_DEMO_SCENE_libero_demo_behaviors.bddl']
# Encountered some failures:  []
# (define (problem LIBERO_Kitchen_Tabletop_Manipulation)
#   (:domain robosuite)
#   (:language libero demo behaviors)
#     (:regions
#       (wooden_cabinet_init_region
#           (:target kitchen_table)
#           (:ranges (
#               (-0.01 -0.31 0.01 -0.29)
#             )
#           )
#           (:yaw_rotation (
#               (3.141592653589793 3.141592653589793)
#             )
#           )
#       )
#       (libero_mug_init_region
#           (:target kitchen_table)
#           (:ranges (
#               (-0.025 -0.025 0.025 0.025)
#             )
#           )
#           (:yaw_rotation (
#               (0.0 0.0)
#             )
#           )
#       )
#       (power_drill_init_region
#           (:target kitchen_table)
#           (:ranges (
#               (-0.125 0.125 -0.07500000000000001 0.175)
#             )
#           )
#           (:yaw_rotation (
#               (0.0 0.0)
#             )
#           )
#       )
#       (top_side
#           (:target wooden_cabinet_1)
#       )
#       (top_region
#           (:target wooden_cabinet_1)
#       )
#       (middle_region
#           (:target wooden_cabinet_1)
#       )
#       (bottom_region
#           (:target wooden_cabinet_1)
#       )
#     )
#
#   (:fixtures
#     kitchen_table - kitchen_table
#     wooden_cabinet_1 - wooden_cabinet
#   )
#
#   (:objects
#     libero_mug_1 - libero_mug
#     power_drill_1 - power_drill
#   )
#
#   (:obj_of_interest
#   )
#
#   (:init
#     (On libero_mug_1 kitchen_table_libero_mug_init_region)
#     (On power_drill_1 kitchen_table_power_drill_init_region)
#     (On wooden_cabinet_1 kitchen_table_wooden_cabinet_init_region)
#   )
#
#   (:goal
#     (And (Open wooden_cabinet_1_top_region) (In power_drill_1 wooden_cabinet_1_top_region))
#   )
#
# )
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 35
#      26 import torchvision
#      29 env_args = {
#      30     "bddl_file_name": bddl_file_names[0],
#      31     "camera_heights": 256,
#      32     "camera_widths": 256
#      33 }
# ---> 35 env = OffScreenRenderEnv(**env_args)
#      36 obs = env.reset()
#      37 display(Image.fromarray(obs["agentview_image"][::-1]))
#
# File ~/Documents/LIBERO/libero/libero/envs/env_wrapper.py:161, in OffScreenRenderEnv.__init__(self, **kwargs)
#     159 kwargs["has_renderer"] = False
#     160 kwargs["has_offscreen_renderer"] = True
# --> 161 super().__init__(**kwargs)
#
# File ~/Documents/LIBERO/libero/libero/envs/env_wrapper.py:56, in ControlEnv.__init__(self, bddl_file_name, robots, controller, gripper_types, initialization_noise, use_camera_obs, has_renderer, has_offscreen_renderer, render_camera, render_collision_mesh, render_visual_mesh, render_gpu_device_id, control_freq, horizon, ignore_done, hard_reset, camera_names, camera_heights, camera_widths, camera_depths, camera_segmentations, renderer, renderer_config, **kwargs)
#      54 self.domain_name = problem_info["domain_name"]
#      55 self.language_instruction = problem_info["language_instruction"]
# ---> 56 self.env = TASK_MAPPING[self.problem_name](
#      57     bddl_file_name,
#      58     robots=robots,
#      59     controller_configs=controller_configs,
#      60     gripper_types=gripper_types,
#      61     initialization_noise=initialization_noise,
#      62     use_camera_obs=use_camera_obs,
#      63     has_renderer=has_renderer,
#      64     has_offscreen_renderer=has_offscreen_renderer,
#      65     render_camera=render_camera,
#      66     render_collision_mesh=render_collision_mesh,
#      67     render_visual_mesh=render_visual_mesh,
#      68     render_gpu_device_id=render_gpu_device_id,
#      69     control_freq=control_freq,
#      70     horizon=horizon,
#      71     ignore_done=ignore_done,
#      72     hard_reset=hard_reset,
#      73     camera_names=camera_names,
#      74     camera_heights=camera_heights,
#      75     camera_widths=camera_widths,
#      76     camera_depths=camera_depths,
#      77     camera_segmentations=camera_segmentations,
#      78     renderer=renderer,
#      79     renderer_config=renderer_config,
#      80     **kwargs,
#      81 )
#
# File ~/Documents/LIBERO/libero/libero/envs/problems/libero_kitchen_tabletop_manipulation.py:42, in Libero_Kitchen_Tabletop_Manipulation.__init__(self, bddl_file_name, *args, **kwargs)
#      32 if "scene_properties" not in kwargs or kwargs["scene_properties"] is None:
#      33     kwargs.update(
#      34         {
#      35             "scene_properties": {
#    (...)
#      39         }
#      40     )
# ---> 42 super().__init__(bddl_file_name, *args, **kwargs)
#
# File ~/Documents/LIBERO/libero/libero/envs/bddl_base_domain.py:135, in BDDLBaseDomain.__init__(self, bddl_file_name, robots, env_configuration, controller_configs, gripper_types, initialization_noise, use_latch, use_camera_obs, use_object_obs, reward_scale, reward_shaping, placement_initializer, object_property_initializers, has_renderer, has_offscreen_renderer, render_camera, render_collision_mesh, render_visual_mesh, render_gpu_device_id, control_freq, horizon, ignore_done, hard_reset, camera_names, camera_heights, camera_widths, camera_depths, camera_segmentations, renderer, table_full_size, workspace_offset, arena_type, scene_xml, scene_properties, **kwargs)
#     132 self._arena_xml = os.path.join(self.custom_asset_dir, scene_xml)
#     133 self._arena_properties = scene_properties
# --> 135 super().__init__(
#     136     robots=robots,
#     137     env_configuration=env_configuration,
#     138     controller_configs=controller_configs,
#     139     mount_types="default",
#     140     gripper_types=gripper_types,
#     141     initialization_noise=initialization_noise,
#     142     use_camera_obs=use_camera_obs,
#     143     has_renderer=has_renderer,
#     144     has_offscreen_renderer=has_offscreen_renderer,
#     145     render_camera=render_camera,
#     146     render_collision_mesh=render_collision_mesh,
#     147     render_visual_mesh=render_visual_mesh,
#     148     render_gpu_device_id=render_gpu_device_id,
#     149     control_freq=control_freq,
#     150     horizon=horizon,
#     151     ignore_done=ignore_done,
#     152     hard_reset=hard_reset,
#     153     camera_names=camera_names,
#     154     camera_heights=camera_heights,
#     155     camera_widths=camera_widths,
#     156     camera_depths=camera_depths,
#     157     camera_segmentations=camera_segmentations,
#     158     renderer=renderer,
#     159     **kwargs,
#     160 )
#
# File ~/miniconda3/envs/libero/lib/python3.8/site-packages/robosuite/environments/manipulation/manipulation_env.py:162, in ManipulationEnv.__init__(self, robots, env_configuration, controller_configs, mount_types, gripper_types, initialization_noise, use_camera_obs, has_renderer, has_offscreen_renderer, render_camera, render_collision_mesh, render_visual_mesh, render_gpu_device_id, control_freq, horizon, ignore_done, hard_reset, camera_names, camera_heights, camera_widths, camera_depths, camera_segmentations, renderer, renderer_config)
#     154 robot_configs = [
#     155     {
#     156         "gripper_type": gripper_types[idx],
#     157     }
#     158     for idx in range(num_robots)
#     159 ]
#     161 # Run superclass init
# --> 162 super().__init__(
#     163     robots=robots,
#     164     env_configuration=env_configuration,
#     165     controller_configs=controller_configs,
#     166     mount_types=mount_types,
#     167     initialization_noise=initialization_noise,
#     168     use_camera_obs=use_camera_obs,
#     169     has_renderer=has_renderer,
#     170     has_offscreen_renderer=has_offscreen_renderer,
#     171     render_camera=render_camera,
#     172     render_collision_mesh=render_collision_mesh,
#     173     render_visual_mesh=render_visual_mesh,
#     174     render_gpu_device_id=render_gpu_device_id,
#     175     control_freq=control_freq,
#     176     horizon=horizon,
#     177     ignore_done=ignore_done,
#     178     hard_reset=hard_reset,
#     179     camera_names=camera_names,
#     180     camera_heights=camera_heights,
#     181     camera_widths=camera_widths,
#     182     camera_depths=camera_depths,
#     183     camera_segmentations=camera_segmentations,
#     184     robot_configs=robot_configs,
#     185     renderer=renderer,
#     186     renderer_config=renderer_config,
#     187 )
#
# File ~/miniconda3/envs/libero/lib/python3.8/site-packages/robosuite/environments/robot_env.py:214, in RobotEnv.__init__(self, robots, env_configuration, mount_types, controller_configs, initialization_noise, use_camera_obs, has_renderer, has_offscreen_renderer, render_camera, render_collision_mesh, render_visual_mesh, render_gpu_device_id, control_freq, horizon, ignore_done, hard_reset, camera_names, camera_heights, camera_widths, camera_depths, camera_segmentations, robot_configs, renderer, renderer_config)
#     200 self.robot_configs = [
#     201     dict(
#     202         **{
#    (...)
#     210     for idx, robot_config in enumerate(robot_configs)
#     211 ]
#     213 # Run superclass init
# --> 214 super().__init__(
#     215     has_renderer=has_renderer,
#     216     has_offscreen_renderer=self.has_offscreen_renderer,
#     217     render_camera=render_camera,
#     218     render_collision_mesh=render_collision_mesh,
#     219     render_visual_mesh=render_visual_mesh,
#     220     render_gpu_device_id=render_gpu_device_id,
#     221     control_freq=control_freq,
#     222     horizon=horizon,
#     223     ignore_done=ignore_done,
#     224     hard_reset=hard_reset,
#     225     renderer=renderer,
#     226     renderer_config=renderer_config,
#     227 )
#
# File ~/miniconda3/envs/libero/lib/python3.8/site-packages/robosuite/environments/base.py:137, in MujocoEnv.__init__(self, has_renderer, has_offscreen_renderer, render_camera, render_collision_mesh, render_visual_mesh, render_gpu_device_id, control_freq, horizon, ignore_done, hard_reset, renderer, renderer_config)
#     134 self._load_model()
#     136 # Initialize the simulation
# --> 137 self._initialize_sim()
#     139 # initializes the rendering
#     140 self.initialize_renderer()
#
# File ~/miniconda3/envs/libero/lib/python3.8/site-packages/robosuite/environments/base.py:230, in MujocoEnv._initialize_sim(self, xml_string)
#     227     xml = self._xml_processor(xml)
#     229 # Create the simulation instance
# --> 230 self.sim = MjSim.from_xml_string(xml)
#     232 # run a single step to make sure changes have propagated through sim state
#     233 self.sim.forward()
#
# File ~/miniconda3/envs/libero/lib/python3.8/site-packages/robosuite/utils/binding_utils.py:1072, in MjSim.from_xml_string(cls, xml)
#    1070 @classmethod
#    1071 def from_xml_string(cls, xml):
# -> 1072     model = mujoco.MjModel.from_xml_string(xml)
#    1073     return cls(model)
#
# ValueError: Error: mass and inertia of moving bodies must be larger than mjMINVAL
# Element name 'power_drill_1_main', id 25, line 465
